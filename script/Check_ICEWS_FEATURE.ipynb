# %% [markdown]
# # Protest Events

# %%
import json
protest_kcf = "/home/tskatom/workspace/icews_model/data/handbook_words/Egypt_keywords_count.json"
protest_kc = json.load(open(protest_kcf))

# %%
protest_kc
sorted_protest_kc = {}
for day in protest_kc:
    word_count = protest_kc[day]
    sorted_word_count = sorted([(k, v) for k,v in word_count.items()], key=lambda x:x[1], reverse=True)
    sorted_protest_kc[day] = sorted_word_count

# %%
sorted_protest_kc
days = sorted(sorted_protest_kc.keys())
for day in days:
    w_set = sorted_protest_kc[day]
    print day
    for w, c in w_set[:10]:
        print '\t', w, gs.translate(w, 'zh')
# Out:
# 2014-04-01
# 	تظاهر
# 演示
# 	انقطاع
# 切断
# 	احتجاج
# 抗议
# 	إضراب
# 罢工
# 	المتظاهرين
# 抗议者
# 	اعتصام
# 静坐
# 	التظاهر
# 假装
# 	مظاهرات
# 示威
# 	احتجاجا
# 抗议
# 	اضطراب
# 焦虑
# 2014-04-02
# 	تظاهر
# 演示
# 	انقطاع
# 切断
# 	إضراب
# 罢工
# 	التظاهر
# 假装
# 	المتظاهرين
# 抗议者
# 	احتجاج
# 抗议
# 	مظاهرات
# 示威
# 	اعتصام
# 静坐
# 	احتجاجا
# 抗议
# 	اضطراب
# 焦虑
# 2014-04-03
# 	تظاهر
# 演示
# 	انقطاع
# 切断
# 	احتجاج
# 抗议
# 	مظاهرات
# 示威
# 	التظاهر
# 假装
# 	إضراب
# 罢工
# 	اعتصام
# 静坐
# 	احتجاجا
# 抗议
# 	المتظاهرين
# 抗议者
# 	اضطراب
# 焦虑
# 2014-04-04
# 	تظاهر
# 演示
# 	احتجاج
# 抗议
# 	مظاهرات
# 示威
# 	مسيرات
# 游行
# 	التظاهر
# 假装
# 	احتجاجا
# 抗议
# 	انقطاع
# 切断
# 	اعتصام
# 静坐
# 	إضراب
# 罢工
# 	المتظاهرين
# 抗议者
# 2014-04-05
# 	تظاهر
# 演示
# 	إضراب
# 罢工
# 	احتجاج
# 抗议
# 	التظاهر
# 假装
# 	مظاهرات
# 示威
# 	المتظاهرين
# 抗议者
# 	اعتصام
# 静坐
# 	اضطراب
# 焦虑
# 	احتجاجا
# 抗议
# 	انقطاع
# 切断
# 2014-04-06
# 	تظاهر
# 演示
# 	احتجاج
# 抗议
# 	التظاهر
# 假装
# 	مظاهرات
# 示威
# 	اعتصام
# 静坐
# 	إضراب
# 罢工
# 	المتظاهرين
# 抗议者
# 	احتجاجا
# 抗议
# 	انقطاع
# 切断
# ...

# %%
import goslate 
gs = goslate.Goslate()
f = "/raid/tskatom/arabia_handbook_keywords_count_trace/arabia-news-2014-11-16-19-16-51"
posts = [json.loads(l) for l in open(f)]

# %%
for p in posts[100:130]:
    
    fullText = p['FullText']
    title = p['Caption']
    places = p['Places']
    try:
        print '-----------TITLE---------------------------->', gs.translate(title, 'zh')
        print '\t-----------CONTENT---------------------------->', gs.translate(fullText, 'zh')
        if places:
            for pl in places:
                print '=-=LOCATIONS=-=\t',pl['Name'], gs.translate(pl['Name'], 'en')
        persons = p['Persons']
        
        if persons:
            for pe in persons:
                print '===PERSONS===\t',pe['Name'], gs.translate(pe['Name'], 'en')
        keywords = p['keywords_count']
        print '\t===KEYWORDS===\t'
        for word in keywords:
            print word, keywords[word], gs.translate(word, 'zh')
    
        print '\n'
    except:
        pass
# Out:
# -----------TITLE---------------------------->
# 通过对怀旧教授/法蒂玛孜然愤怒
# 	-----------CONTENT---------------------------->
# 巫妖王之怒怀旧....
#
#  燃烧的精神内疚内存Tsrha Tzebha
# Kalshmua ......我需要你严重Tbosrna，烟雾从香炉身体呻吟的气味
# 离开雾晶体眼泪..taatazahr你不知道的秘密Ohoaqa的，这些
# 冷漠每天自杀我，我跟着你所有的细节......迷宫抱我
#  她幻想在时间的走廊，空间没有颜色，背着她的想法非晶
# 默默祈祷：“Rafka心脏千夫长押拿向往..oherb从自己活在一个午睡的残骸
# 展馆的恢复周年迫使我梦想这个时候...回去不唱的旋律
# 在微风中摇曳的花朵
# Angamha，并在Ohjanaa翩翩起舞的蝴蝶，我看到我周围祈祷祈祷缺席
# 如果没有祈祷或咒语失去了他的声音回荡向往的歌曲，看着tayammum室
# 因为，加入了众和力分配体瘦乏善可陈Vtakhzna Temtemat
#  风能和我的记忆喧嚣，你的特征的图像闪烁Ngzona Verak漫游不会死的内部漂亮的夜晚走路，走路，让我Otardek急切地想Aaskah
# 我的脚了加速较轻，以免在我面前Idrickk脉搏，不来你的心
# 很快你认为我傲慢Olahakk。话是徒劳的无与伦比的跑下来告诉
# 用低沉的声音，我听到内部Oninha：不要让我离开，阅读之前，你不要离开
# 删除的记忆和符号的页边距每个Hehgh叹息行上每个字母
# 点缀史诗渴望和等待......感觉到感觉手没有失去Dfoha天我的肩膀上
# Tgzptna风为银行前往你，与你每次在Notes中消失的姿态
# 曲折，消失在你的眼睛Alsahrtin ...回声呼吸重复Tnhidat，跳舞
# 节奏饥饿的嘴唇一吻淬火热衷季节，徒劳地试图从醒来
#  我的梦想......你在的地方没有忍住泪水的敬畏，但隐瞒，直到那
# 喧嚣的外套盖傲慢......下雨了最疯狂的梦想伴随着我的朝圣而坐了两个
#  从日出到日落热切向往......在我的论文，泛黄且分散寻找
# 老橡皮擦Ontzek我没有上Askink，成为后需要
# ...

# %% [markdown]
# # Coerce Events

# %%
import json
coerce_kcf = "/home/tskatom/workspace/icews_model/data/coerce_keywords/Egypt_keywords_count.json"
coerce_kc = json.load(open(coerce_kcf))

# %%
coerce_kc
sorted_coerce_kc = {}
for day in coerce_kc:
    word_count = coerce_kc[day]
    sorted_word_count = sorted([(k, v) for k,v in word_count.items()], key=lambda x:x[1], reverse=True)
    sorted_coerce_kc[day] = sorted_word_count

# %%
sorted_coerce_kc
days = sorted(sorted_coerce_kc.keys())
for day in days:
    w_set = sorted_coerce_kc[day]
    print day
    for w, c in w_set[:10]:
        print '\t', w, gs.translate(w, 'zh')
# Out:
# 2014-04-01
# 	تحقيق
# 调查
# 	تنفيذ
# 执行
# 	الشرطة
# 警察
# 	الجيش
# 军队
# 	رفض
# 拒绝
# 	مطالب
# 博客
# 	إصابة
# 感染
# 	القبض
# 被捕
# 	فرض
# 征收
# 	سجن
# 监狱
# 2014-04-02
# 	تحقيق
# 调查
# 	الشرطة
# 警察
# 	تنفيذ
# 执行
# 	الجيش
# 军队
# 	رفض
# 拒绝
# 	إصابة
# 感染
# 	مطالب
# 博客
# 	القبض
# 被捕
# 	فرض
# 征收
# 	سجن
# 监狱
# 2014-04-03
# 	تحقيق
# 调查
# 	الشرطة
# 警察
# 	تنفيذ
# 执行
# 	الجيش
# 军队
# 	رفض
# 拒绝
# 	مطالب
# 博客
# 	إصابة
# 感染
# 	حظر
# 禁令
# 	القبض
# 被捕
# 	سجن
# 监狱
# 2014-04-04
# 	تحقيق
# 调查
# 	الشرطة
# 警察
# 	تنفيذ
# 执行
# 	الجيش
# 军队
# 	رفض
# 拒绝
# 	سجن
# 监狱
# 	مطالب
# 博客
# 	حظر
# 禁令
# 	القبض
# 被捕
# 	إصابة
# 感染
# 2014-04-05
# 	تحقيق
# 调查
# 	الشرطة
# 警察
# 	تنفيذ
# 执行
# 	رفض
# 拒绝
# 	حظر
# 禁令
# 	مطالب
# 博客
# 	الجيش
# 军队
# 	إصابة
# 感染
# 	القبض
# 被捕
# 	سجن
# 监狱
# 2014-04-06
# 	تحقيق
# 调查
# 	الشرطة
# 警察
# 	تنفيذ
# 执行
# 	الجيش
# 军队
# 	مطالب
# 博客
# 	رفض
# 拒绝
# 	إصابة
# 感染
# 	حظر
# 禁令
# 	القبض
# 被捕
# 	فرض
# 征收
# 2014-04-07
# 	تحقيق
# 调查
# 	الشرطة
# 警察
# 	تنفيذ
# 执行
# 	رفض
# 拒绝
# 	مطالب
# 博客
# 	الجيش
# 军队
# 	القبض
# 被捕
# ...

# %%
import goslate 
gs = goslate.Goslate()
f = "/raid/tskatom/coerce_keywords_count_trace/arabia-2014-05-15-23-59-59"
posts = [json.loads(l) for l in open(f)]

# %%
for p in posts[200:230]:
    
    fullText = p['FullText']
    title = p['Caption']
    places = p['Places']
    try:
        print '-----------TITLE---------------------------->', gs.translate(title, 'zh')
        print '\t-----------CONTENT---------------------------->', gs.translate(fullText, 'zh').replace("\n","")
        if places:
            for pl in places:
                print '=-=LOCATIONS=-=\t',pl['Name'], gs.translate(pl['Name'], 'en')
        persons = p['Persons']
        
        if persons:
            for pe in persons:
                print '===PERSONS===\t',pe['Name'], gs.translate(pe['Name'], 'en')
        keywords = p['keywords_count']
        print '\t===KEYWORDS===\t'
        for word in keywords:
            print word, keywords[word], gs.translate(word, 'zh')
    
        print '\n'
    except:
        pass
# Out:
# -----------TITLE---------------------------->
# 萨尔玛Sabahi支持者思思
# 	-----------CONTENT---------------------------->
# 导演萨尔玛上午，总统候选人Hamdeen，对手候选人尖锐的批评，她的父亲，阿卜杜勒 - 法塔赫人，思思，约没有他的选举程序问题，而不是出现在空气中的媒体对他的会议形式的儿子。她说，“脸谱”的头版：“每Sahabi支持者思思凸轮我不知道回答一个问题，我想提醒我：”安托Haeven埃利思思在他7月3日美丽的埃及人民，军队不是国家的责任“？她补充说：“在总统大选..什么方式Mandikuh拦截Tantkhbwa候选人Manduc平台Hthaspuh什么药？..？“最终，我知道Ogbakoa可能被啮合月份已经是革命，但这是人民的革命和保存的烈士，并没有对他们影响很大”，“解释任何腐败几乎所有的旧政权谁进行他们的革命DVD的带动下，穆巴拉克本人亲娘娘腔的符号？ “。说，他的儿子日场：“在整个世界的总统大选至少有两个总统候选人需要Taataml包括合适的人选反对对哈瓦公开辩论，整个人面前，目主要是因为人们去正确的..说明任何拒绝思思竞选辩论！是大的弱点，也不害怕对手候选人的力量！“至于在空中直接会晤的非外观思思，她说，“总统Hikon Ayesh亮”GS哈瓦“我不Hicod国”蒙太奇“..说明任何非外观思思P哈瓦不是一劳永逸的LES会议Mmnottagh？！并解释任何不符合人们流行的会议中心是必不可少的脱传统在世界上任何竞选脱落呢？网格可以去Atvsr他对人还是缺乏自信“来”？“并且结束她的讲话，他说：“写以最大的尊重德问题和因为我的保险公司的竞争需要的是诚实，添加和Ayza你知道自己的答案以最大的口味补充您的候选人......雅房地产投资信托基金回应认真意见，并感谢您的耐心和Khalako Vachrin总统不可能和叶集和人民的其余.. EHNA谁Bagaan一些“ 广告服务|使用协议和隐私声明|联系我们版权所有©2012 akhbar-elwatan.com所有权利。所有网站上的消息都来自外部来源和内容提供商的责任，网站不承担此类新闻的真实性和准确性承担任何责任。
# ===PERSONS===	حمدين صباحي
# Hamdeen
# ...
